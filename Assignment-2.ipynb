# %% [markdown]
# # Assignment - 2
# ## 1. Create a List L that is defined as= [10, 20, 30, 40, 50, 60, 70, 80].
# 1. WAP to add 200 and 300 to L.
# 2. WAP to remove 10 and 30 from L.
# 3. WAP to sort L in ascending order.
# 4. WAP to sort L in descending order.

# %%
L = [10, 20, 30, 40, 50, 60, 70, 80]
L.append(200)
print("List after adding 200:", L)
L.append(300)
print("List after adding 300:", L)
L.remove(10)
print("List after removing 10:", L)
L.remove(30)
print("List after removing 30:", L)
L.sort()
print("List after sorting in ascending order:", L)
L.sort(reverse = True)
print("List after sorting in descending order:", L)
# Out:
# List after adding 200: [10, 20, 30, 40, 50, 60, 70, 80, 200]
# List after adding 300: [10, 20, 30, 40, 50, 60, 70, 80, 200, 300]
# List after removing 10: [20, 30, 40, 50, 60, 70, 80, 200, 300]
# List after removing 30: [20, 40, 50, 60, 70, 80, 200, 300]
# List after sorting in ascending order: [20, 40, 50, 60, 70, 80, 200, 300]
# List after sorting in descending order: [300, 200, 80, 70, 60, 50, 40, 20]

# %% [markdown]
# ## 2. Create a tuple of marks scored as scores = (45, 89.5, 76, 45.4, 89, 92, 58, 45) and perform the following operations using tuple functions:
# 1. Identify the highest score and its index in the tuple.
# 2. Find the lowest score and count how many times it appears.
# 3. Reverse the tuple and return it as a list.
# 4. Check if a specific score ‘76’ (input by the user) is present in the tuple and print its first occurrence index, or a message saying it’s not present.

# %%
scores = (45, 89.5, 76, 45.4, 89, 92, 58, 45)
highest_score = max(scores)
ind = scores.index(highest_score)
print(f"{highest_score} is the highest score at index {ind}")
lowest_score = min(scores)
count_lowest = scores.count(lowest_score)
print(f"{lowest_score} is the lowest score which occurs {count_lowest} times")
scores = scores[::-1]
print("The tuple after reversing:", list(scores))
score = int(input("Enter the score:"))
if score in scores:
    print(f"{score} occurs at index {scores.index(score)} in scores")
else:
    print(f"{score} is not present in scores")
# Out:
# 92 is the highest score at index 5
# 45 is the lowest score which occurs 2 times
# The tuple after reversing: [45, 58, 92, 89, 45.4, 76, 89.5, 45]
# Enter the score: 76
# 76 occurs at index 5 in scores

# %% [markdown]
# ## 3. WAP to create a list of 100 random numbers between 100 and 900. Count and print the:
# 1. All odd numbers
# 2. All even numbers
# 3. All prime numbers

# %%
import random
import math
def isPrime(n):
    for i in range(2, int(math.sqrt(n))):
        if n % i == 0:
            return 1
    return 0
l = [random.randint(100, 900) for i in range(100)]
odd = [num for num in l if num % 2 != 0]
even = [num for num in l if num % 2 == 0]
prime = [num for num in l if isPrime(num)]
print("Odd Numbers:")
for i in odd:
    print(i, end = " ")
print("\nEven Numbers:")
for i in even:
    print(i, end = " ")
print("\nPrime Numbers:")
for i in prime:
    print(i, end = " ")
# Out:
# Odd Numbers:
# 311 817 523 885 641 821 257 517 405 591 349 857 737 735 821 373 265 635 447 167 539 191 291 763 459 701 653 373 681 179 513 221 311 677 667 343 427 885 477 195 729 579 673 587 715 389 619 843 165 315 853
# Even Numbers:
# 566 658 580 388 702 234 394 758 620 818 788 534 156 610 214 684 724 266 402 502 332 122 888 360 186 830 586 618 542 558 172 494 434 600 176 224 872 476 156 298 534 594 212 760 620 212 406 686 638
# Prime Numbers:
# 566 658 580 388 702 234 394 817 758 885 620 818 788 534 517 405 156 591 610 737 735 214 265 635 447 684 724 266 539 291 763 459 402 502 332 122 681 888 513 360 186 830 586 221 618 542 667 558 343 427 885 172 494 477 434 600 176 195 729 224 872 476 579 156 298 534 594 715 212 760 620 212 843 406 165 315 686 638

# %% [markdown]
# ## 4. Consider the following two sets, A and B, represen ng scores of two teams in multiple matches.  A = {34, 56, 78, 90}  and B = {78, 45, 90, 23}
# ## WAP to perform the following opera ons using set func ons:
# 1. Find the unique scores achieved by both teams (union of sets).
# 2. Identify the scores that are common to both teams (intersec on of sets).
# 3. Find the scores that are exclusive to each team (symmetric difference).
# 4. Check if the scores of team A are a subset of team B, and if team B's scores are a superset of team A.
# 5. Remove a specific score 𝑋 (input by the user) from set A if it exists. If not, print a message saying it is not present.

# %%
A = {34, 56, 78, 90}
B = {78, 45, 90, 23}
print("The unique scores achieved by both teams are:", A.union(B))
print("The scores that are common to both teams:", A.intersection(B))
print("The scores that are exclusive to each team:", A^B)
if A.issubset(B):
    print("Scores of team A are a subset of team B")
else:
    print("Scores of team A are not a subset of team B")
if B.issuperset(B):
    print("Scores of team B are a superset of team A")
else:
    print("Scores of team B are not a superset of team A")
score = int(input("Enter the score to be removed:"))
if score in A:
    A.remove(score)
else:
    print(f"{score} is not present in A")
# Out:
# The unique scores achieved by both teams are: {34, 45, 78, 23, 56, 90}
# The scores that are common to both teams: {90, 78}
# The scores that are exclusive to each team: {34, 45, 23, 56}
# Scores of team A are not a subset of team B
# Scores of team B are a superset of team A
# Enter the score to be removed: 78

# %% [markdown]
# ## 5. Write a program to rename a key city to a location in the following dictionary.
# ![image.png](attachment:852a9613-bcea-4c6c-aff1-37a5476c374b.png)

# %%
sample_dict = {
    "name" : "Kelly",
    "age" : 25,
    "salary" : 8000,
    "city" : "New York"
}
if "city" in sample_dict:
    sample_dict["location"] = sample_dict.pop("city")
print("Updated Dictionary:", sample_dict)
# Out:
# Updated Dictionary: {'name': 'Kelly', 'age': 25, 'salary': 8000, 'location': 'New York'}
